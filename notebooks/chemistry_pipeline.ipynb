# %%
import pennylane as qml
import torch
import pandas as pd
import numpy as np
import sklearn

print("PennyLane:", qml.__version__)
print("PyTorch:", torch.__version__)
print("Ready for Quantum Nexus 🚀")
# Out:
# PennyLane: 0.45.0
# PyTorch: 2.12.0+cpu
# Ready for Quantum Nexus 🚀

# %%
from rdkit import Chem
print("RDKit working")
# Out:
# RDKit working
